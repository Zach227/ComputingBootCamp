# %% [markdown]
# <a href="https://colab.research.google.com/github/Zach227/ComputingBootCamp/blob/main/proj3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torchvision.transforms as transforms

# %%
# %%bash
# mv ../data2.zip ./
# unzip data2.zip

# %% [markdown]
# ## Create Datasets

# %%
import numpy as np
import random

def set_seed(seed: int = 42) -> None:
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    # When running on the CuDNN backend, two further options must be set
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    # Set a fixed value for the hash seed
    print(f"Random seed set as {seed}")

# %%
from custom_dataset import CustomImageDataset
from torch.utils.data import DataLoader
set_seed(11)

transform = transforms.Compose(
    [
        transforms.Resize((120, 120)),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ]
)
batch_size = 2

data = CustomImageDataset(
    "data/train/train.csv", "data/train/", transform=transform
)

train_val_size = int(0.9 * len(data))
test_size = len(data) - train_val_size
train_size = int(0.9 * train_val_size)
val_size = train_val_size - train_size

train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(
    data, [train_size, val_size, test_size]
)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)


classes = ["None", "glioma", "meningioma", "pituitary"]
# Out:
# Random seed set as 11

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# image, label = trainset.__getitem__(220)
# print(image.shape)

# get some random training images
dataiter = iter(train_loader)
images, labels = next(dataiter)

# # show images
imshow(torchvision.utils.make_grid(images))
print(" ".join(f"{classes[labels[j]]:5s}" for j in range(batch_size)))
print(images.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# meningioma glioma
# torch.Size([2, 3, 120, 120])

# %% [markdown]
# ## Dummy Classifier

# %%
from sklearn.dummy import DummyClassifier

dummy_classifier = DummyClassifier(strategy="uniform")
train_labels = []

for images, labels in train_loader:
  for label in labels:
    train_labels.append(label)

dummy_classifier.fit(train_dataset, train_labels)


# test the dummy classifier on the test set
correct = 0
total = 0
for images, labels in test_loader:
    outputs = dummy_classifier.predict(images)
    for i in range(len(outputs)):
        if outputs[i] == labels[i]:
            correct += 1
        total += 1

print("Accuracy of the network on the test images: %d %%" % (100 * correct / total))
# Out:
# Accuracy of the network on the test images: 25 %

# %% [markdown]
# ## Define Networks

# %%
import torch.nn as nn
import torch.nn.functional as F


class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3, stride=1, padding=1)
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, stride=1, padding=1)
        self.pool2 = nn.MaxPool2d(2, 2)
        self.conv3 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.pool3 = nn.MaxPool2d(2, 2)

        self.fc1 = nn.Linear(32 * 15 * 15, 64)  # Adjust the input size based on your image dimensions
        self.fc2 = nn.Linear(64, 4)

    def forward(self, x):
        # Convolutional layers
        x = self.pool1(F.relu(self.conv1(x)))
        x = self.pool2(F.relu(self.conv2(x)))
        x = self.pool3(F.relu(self.conv3(x)))

        # Flatten the output for the fully connected layers
        x = x.view(-1, 32 * 15 * 15)  # Adjust the size based on your image dimensions

        # Fully connected layers
        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# %%
class DeeperCNN(nn.Module):
    def __init__(self):
        super(DeeperCNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3, stride=1, padding=1)
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, stride=1, padding=1)
        self.pool2 = nn.MaxPool2d(2, 2)
        self.conv3 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.pool3 = nn.MaxPool2d(2, 2)

        # Additional convolutional layer
        self.conv4 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.pool4 = nn.MaxPool2d(2, 2)

        self.fc1 = nn.Linear(64 * 7 * 7, 128)  # Adjust the input size based on your image dimensions
        self.fc2 = nn.Linear(128, 64)  # Extra fully connected layer
        self.fc3 = nn.Linear(64, 4)

    def forward(self, x):
        # Convolutional layers
        x = self.pool1(F.relu(self.conv1(x)))
        x = self.pool2(F.relu(self.conv2(x)))
        x = self.pool3(F.relu(self.conv3(x)))
        x = self.pool4(F.relu(self.conv4(x)))  # Additional layer

        # Flatten the output for the fully connected layers
        x = x.view(-1, 64 * 7 * 7)  # Adjust the size based on your image dimensions

        # Fully connected layers
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))  # Extra fully connected layer
        x = self.fc3(x)

        return x

# %%
import torch.nn as nn
import torch.nn.functional as F


class WiderCNN(nn.Module):
    def __init__(self):
        super(WiderCNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1)
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.pool2 = nn.MaxPool2d(2, 2)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.pool3 = nn.MaxPool2d(2, 2)

        self.fc1 = nn.Linear(64 * 15 * 15, 128)  # Adjust the input size based on your image dimensions
        self.fc2 = nn.Linear(128, 4)

    def forward(self, x):
        # Convolutional layers
        x = self.pool1(F.relu(self.conv1(x)))
        x = self.pool2(F.relu(self.conv2(x)))
        x = self.pool3(F.relu(self.conv3(x)))

        # Flatten the output for the fully connected layers
        x = x.view(-1, 64 * 15 * 15)  # Adjust the size based on your image dimensions

        # Fully connected layers
        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# %% [markdown]
# ## Hyperparameter Sweep

# %%
def set_seed(seed: int = 42) -> None:
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    # When running on the CuDNN backend, two further options must be set
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    # Set a fixed value for the hash seed
    print(f"Random seed set as {seed}")

# %%
import torch.optim as optim


results_dict = {}
for criterion in [nn.CrossEntropyLoss()]:
  for learning_rate in [0.005, 0.001]:
    for opt in ['Adam', 'RMSprop', 'SGD']:

      set_seed(31)
      model = WiderCNN()
      if opt == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=learning_rate)
      elif opt == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)
      elif opt == 'RMSprop':
        optimizer = optim.RMSprop(model.parameters(), lr=learning_rate)


      device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
      model.to(device)

      val_stats = []
      for epoch in range(20):  # loop over the dataset multiple times
          for i, data in enumerate(train_loader, 0):
              # get the inputs; data is a list of [inputs, labels]
              inputs, labels = data[0].to(device), data[1].to(device)

              # zero the parameter gradients
              optimizer.zero_grad()

              # forward + backward + optimize
              outputs = model(inputs)
              loss = criterion(outputs, labels)
              loss.backward()
              optimizer.step()

          # Validation
          correct = 0
          total = 0
          with torch.no_grad():
              for data in val_loader:
                  inputs, labels = data[0].to(device), data[1].to(device)
                  outputs = model(inputs)
                  _, predicted = torch.max(outputs.data, 1)  # returns max value, indices
                  total += labels.size(0)
                  correct += (predicted == labels).sum().item()
          accuracy = correct / total
          hyp_params = f'batch_size={batch_size}, criterion={criterion}, learning rate={learning_rate}, optimizer = {opt}, epochs = {epoch+1}'
          results_dict[hyp_params] = accuracy
          print(f'{hyp_params} ---> {1-accuracy}')
# Out:
# Random seed set as 31
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 1 ---> 0.7142857142857143
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 2 ---> 0.7074829931972789
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 3 ---> 0.7551020408163265
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 4 ---> 0.7142857142857143
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 5 ---> 0.7551020408163265
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 6 ---> 0.7551020408163265
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 7 ---> 0.7551020408163265
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 8 ---> 0.7551020408163265
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 9 ---> 0.7551020408163265
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 10 ---> 0.7551020408163265
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 11 ---> 0.7551020408163265
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 12 ---> 0.7074829931972789
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 13 ---> 0.7142857142857143
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 14 ---> 0.7551020408163265
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 15 ---> 0.7551020408163265
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 16 ---> 0.7551020408163265
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 17 ---> 0.7551020408163265
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 18 ---> 0.7551020408163265
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 19 ---> 0.7142857142857143
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = Adam, epochs = 20 ---> 0.7551020408163265
# Random seed set as 31
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 1 ---> 0.3537414965986394
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 2 ---> 0.4319727891156463
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 3 ---> 0.30272108843537415
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 4 ---> 0.22789115646258506
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 5 ---> 0.22448979591836737
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 6 ---> 0.20068027210884354
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 7 ---> 0.15646258503401356
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 8 ---> 0.23129251700680276
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 9 ---> 0.13265306122448983
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 10 ---> 0.1768707482993197
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 11 ---> 0.16326530612244894
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 12 ---> 0.16666666666666663
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 13 ---> 0.1462585034013606
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 14 ---> 0.25850340136054417
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 15 ---> 0.12925170068027214
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 16 ---> 0.1394557823129252
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 17 ---> 0.1462585034013606
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 18 ---> 0.13605442176870752
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 19 ---> 0.19727891156462585
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = RMSprop, epochs = 20 ---> 0.13265306122448983
# Random seed set as 31
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 1 ---> 0.36734693877551017
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 2 ---> 0.2857142857142857
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 3 ---> 0.23469387755102045
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 4 ---> 0.1768707482993197
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 5 ---> 0.2142857142857143
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 6 ---> 0.19727891156462585
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 7 ---> 0.13605442176870752
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 8 ---> 0.12585034013605445
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 9 ---> 0.108843537414966
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 10 ---> 0.11904761904761907
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 11 ---> 0.08163265306122447
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 12 ---> 0.09863945578231292
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 13 ---> 0.108843537414966
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 14 ---> 0.09183673469387754
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 15 ---> 0.10204081632653061
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 16 ---> 0.08503401360544216
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 17 ---> 0.08163265306122447
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 18 ---> 0.08503401360544216
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 19 ---> 0.08163265306122447
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.005, optimizer = SGD, epochs = 20 ---> 0.08163265306122447
# Random seed set as 31
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 1 ---> 0.282312925170068
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 2 ---> 0.2142857142857143
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 3 ---> 0.13265306122448983
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 4 ---> 0.13605442176870752
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 5 ---> 0.11564625850340138
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 6 ---> 0.11904761904761907
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 7 ---> 0.11564625850340138
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 8 ---> 0.108843537414966
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 9 ---> 0.09863945578231292
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 10 ---> 0.11564625850340138
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 11 ---> 0.11904761904761907
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 12 ---> 0.108843537414966
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 13 ---> 0.12925170068027214
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 14 ---> 0.09863945578231292
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 15 ---> 0.1054421768707483
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 16 ---> 0.09523809523809523
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 17 ---> 0.1054421768707483
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 18 ---> 0.11904761904761907
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 19 ---> 0.11224489795918369
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = Adam, epochs = 20 ---> 0.11564625850340138
# Random seed set as 31
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 1 ---> 0.22448979591836737
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 2 ---> 0.1428571428571429
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 3 ---> 0.13605442176870752
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 4 ---> 0.11224489795918369
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 5 ---> 0.108843537414966
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 6 ---> 0.13605442176870752
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 7 ---> 0.061224489795918324
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 8 ---> 0.09863945578231292
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 9 ---> 0.09863945578231292
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 10 ---> 0.07823129251700678
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 11 ---> 0.08503401360544216
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 12 ---> 0.08843537414965985
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 13 ---> 0.09523809523809523
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 14 ---> 0.09523809523809523
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 15 ---> 0.09183673469387754
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 16 ---> 0.09183673469387754
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 17 ---> 0.08843537414965985
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 18 ---> 0.09183673469387754
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 19 ---> 0.15646258503401356
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = RMSprop, epochs = 20 ---> 0.09863945578231292
# Random seed set as 31
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 1 ---> 0.7040816326530612
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 2 ---> 0.4897959183673469
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 3 ---> 0.3979591836734694
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 4 ---> 0.3503401360544217
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 5 ---> 0.33673469387755106
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 6 ---> 0.3197278911564626
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 7 ---> 0.2551020408163265
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 8 ---> 0.22448979591836737
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 9 ---> 0.19047619047619047
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 10 ---> 0.22789115646258506
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 11 ---> 0.20068027210884354
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 12 ---> 0.1768707482993197
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 13 ---> 0.1394557823129252
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 14 ---> 0.15646258503401356
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 15 ---> 0.11904761904761907
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 16 ---> 0.108843537414966
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 17 ---> 0.1768707482993197
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 18 ---> 0.11904761904761907
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 19 ---> 0.09523809523809523
# batch_size=2, criterion=CrossEntropyLoss(), learning rate=0.001, optimizer = SGD, epochs = 20 ---> 0.20748299319727892

# %%
PATH = "./proj3_model.pth"
torch.save(model.state_dict(), PATH)

# %%
dataiter = iter(test_loader)
images, labels = next(dataiter)

# print images
imshow(torchvision.utils.make_grid(images))
print("GroundTruth: ", " ".join(f"{classes[labels[j]]:5s}" for j in range(4)))


net = CNN()
net.load_state_dict(torch.load(PATH))

outputs = net(images)

_, predicted = torch.max(outputs, 1)

print("Predicted: ", " ".join(f"{classes[predicted[j]]:5s}" for j in range(4)))
# Out:
# /Users/zacharydriskill/Desktop/ECEN493/envML/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# GroundTruth:  meningioma glioma meningioma glioma
# Predicted:  meningioma glioma pituitary meningioma

# %%
correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in test_loader:
        images, labels = data[0].to(device), data[1].to(device)
        # calculate outputs by running images through the network
        outputs = model(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy of the network on the test images: {100 * correct // total} %")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Accuracy of the network on the test images: 69 %

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in test_loader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = model(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f"Accuracy for class: {classname:5s} is {accuracy:.1f} %")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Accuracy for class: None  is 91.4 %
# Accuracy for class: glioma is 21.0 %
# Accuracy for class: meningioma is 87.8 %
# Accuracy for class: pituitary is 73.0 %
